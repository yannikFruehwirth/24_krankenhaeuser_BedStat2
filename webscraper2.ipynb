# %%
import requests 

r = requests.get("https://services7.arcgis.com/mOBPykOjAyBO2ZKk/ArcGIS/rest/services/Krankenhaus_hospital/FeatureServer/0/query?where=&objectIds=1&time=&geometry=&geometryType=esriGeometryEnvelope&inSR=&spatialRel=esriSpatialRelIntersects&resultType=none&distance=0.0&units=esriSRUnit_Meter&returnGeodetic=false&outFields=&returnGeometry=true&featureEncoding=esriDefault&multipatchOption=xyFootprint&maxAllowableOffset=&geometryPrecision=&outSR=&datumTransformation=&applyVCSProjection=false&returnIdsOnly=false&returnUniqueIdsOnly=false&returnCountOnly=false&returnExtentOnly=false&returnQueryGeometry=false&returnDistinctValues=false&cacheHint=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&having=&resultOffset=&resultRecordCount=&returnZ=false&returnM=false&returnExceededLimitFeatures=true&quantizationParameters=&sqlFormat=none&f=pjson&token=")

# %%
import json

data = json.loads(r.text)

finalData = {}

finalArray = []


for key, value in data.items() :
    if key == "features":
        data2 = value
        data3 = data2[0]
        
        attributes = data3["attributes"]
        name = attributes["name"]
        #print(name)
        
        geometry = data3["geometry"]
        #print(geometry)
        
        finalData[name] = geometry
print(finalData)
# Out:
# {'Kreiskrankenhaus Torgau': {'x': 12.98462900000004, 'y': 51.56156450000003}}

# %% [markdown]
# # Imports

# %%
import json
import requests

# %% [markdown]
# # finalData

# %%
finalData = {}

# %% [markdown]
# # Code

# %%
counter = 1
while counter < 2596:
    r = requests.get("https://services7.arcgis.com/mOBPykOjAyBO2ZKk/ArcGIS/rest/services/Krankenhaus_hospital/FeatureServer/0/query?where=&objectIds="+str(counter)+"&time=&geometry=&geometryType=esriGeometryEnvelope&inSR=&spatialRel=esriSpatialRelIntersects&resultType=none&distance=0.0&units=esriSRUnit_Meter&returnGeodetic=false&outFields=&returnGeometry=true&featureEncoding=esriDefault&multipatchOption=xyFootprint&maxAllowableOffset=&geometryPrecision=&outSR=&datumTransformation=&applyVCSProjection=false&returnIdsOnly=false&returnUniqueIdsOnly=false&returnCountOnly=false&returnExtentOnly=false&returnQueryGeometry=false&returnDistinctValues=false&cacheHint=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&having=&resultOffset=&resultRecordCount=&returnZ=false&returnM=false&returnExceededLimitFeatures=true&quantizationParameters=&sqlFormat=none&f=pjson&token=")
    data = json.loads(r.text)
   
    
    for key, value in data.items() :
        if key == "features":
            data2 = value
            # print(data2)
            data3 = data2[0]
            
        
            attributes = data3["attributes"]
            name = attributes["name"]
            #print(name)
        
            geometry = data3["geometry"]
            #print(geometry)
        
            finalData[name] = geometry
            
    counter = counter +1

# %% [markdown]
# # Dict. -> JSON

# %%
finalData = json.dumps(finalData)
print(finalData)
# Out:
# {"Kreiskrankenhaus Torgau": {"x": 12.98462900000004, "y": 51.56156450000003}, "St. Marienkrankenhaus": {"x": 8.408887718000074, "y": 49.45758308600006}, "Klinik Adorf": {"x": 12.289834300000052, "y": 50.32869660000006}, "SRH Wald-Klinikum Gera": {"x": 12.051077000000078, "y": 50.86843900000008}, "Diakonissenkrankenhaus": {"x": 13.76148255000004, "y": 51.06287122200007}, "Stiftungskrankenhaus N\u00f6rdlingen": {"x": 10.49856310000007, "y": 48.83709290000007}, "Dipl.-Med. Carla Herbst": {"x": 11.099312100000077, "y": 50.65904110000008}, "AMEOS Klinikum Osnabr\u00fcck - Standort Gertrudenring": {"x": 8.049406200000021, "y": 52.28453010000004}, "Kreisklinik Wolfratshausen": {"x": 11.42831760000007, "y": 47.91173560000004}, "Medizinische Klinik": {"x": 8.666616831000056, "y": 49.41621019300004}, "Mund-, Kiefer-, Gesichtschirurgie": {"x": 11.56052470000003, "y": 48.13100140000006}, "Dr. von Haunersches Kinderspital": {"x": 11.55920530000003, "y": 48.130282100000045}, "Poliklinik Zahn\u00e4
# ...

# %%
with open ('krankenhauser.txt', 'w') as json_file:
    json.dump(finalData, json_file)
